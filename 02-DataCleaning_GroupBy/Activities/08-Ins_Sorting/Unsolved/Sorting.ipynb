# %% [markdown]
# # Sorting a DataFrame
#
# [Pandas `sort_values()` documentation](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sort_values.html)

# %% [markdown]
# ### Import Dependencies

# %%
import pandas as pd
import os

# %% [markdown]
# ### Load the data file

# %%
csv_path = os.path.join("..", "Resources","Happiness_2017.csv")

happiness_df = pd.read_csv(csv_path)
happiness_df.head()
# Out:
#        Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 0       Norway               1            7.537      7.594445     7.479556
# 1      Denmark               2            7.522      7.581728     7.462272
# 2      Iceland               3            7.504      7.622030     7.385970
# 3  Switzerland               4            7.494      7.561772     7.426227
# 4      Finland               5            7.469      7.527542     7.410458
#
#    Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 0                  1.616463  1.533524                  0.796667  0.635423
# 1                  1.482383  1.551122                  0.792566  0.626007
# 2                  1.480633  1.610574                  0.833552  0.627163
# 3                  1.564980  1.516912                  0.858131  0.620071
# 4                  1.443572  1.540247                  0.809158  0.617951
#
#    Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 0    0.362012                       0.315964           2.277027
# 1    0.355280                       0.400770           2.313707
# 2    0.475540                       0.153527           2.322715
# 3    0.290549                       0.367007           2.276716
# 4    0.245483                       0.382612           2.430182

# %% [markdown]
# ### Sorting the DataFrame based on "Freedom" column
#
# **NOTE:** By default, `sort_values()` will sort from lowest to highest.

# %%
happiness_df.sort_values("Freedom")
# Out:
#         Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 139      Angola             140            3.795      3.951642     3.638358
# 129       Sudan             130            4.139      4.345747     3.932253
# 144       Haiti             145            3.603      3.734715     3.471285
# 153     Burundi             154            2.905      3.074690     2.735310
# 151       Syria             152            3.462      3.663669     3.260331
# ..          ...             ...              ...           ...          ...
# 1       Denmark               2            7.522      7.581728     7.462272
# 2       Iceland               3            7.504      7.622030     7.385970
# 128    Cambodia             129            4.168      4.278518     4.057483
# 0        Norway               1            7.537      7.594445     7.479556
# 46   Uzbekistan              47            5.971      6.065538     5.876463
#
#      Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 139                  0.858428  1.104412                  0.049869  0.000000
# 129                  0.659517  1.214009                  0.290921  0.014996
# 144                  0.368610  0.640450                  0.277321  0.030370
# 153                  0.091623  0.629794                  0.151611  0.059901
# 151                  0.777153  0.396103                  0.500533  0.081539
# ..                        ...       ...                       ...       ...
# 1                    1.482383  1.551122                  0.792566  0.626007
# 2                    1.480633  1.610574                  0.833552  0.627163
# 128                  0.601765  1.006238                  0.429783  0.633376
# 0                    1.616463  1.533524                  0.796667  0.635423
# 46                   0.786441  1.548969                  0.498273  0.658249
#
#      Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 139    0.097926                       0.069720           1.614482
# 129    0.182317                       0.089848           1.687066
# 144    0.489204                       0.099872           1.697168
# 153    0.204435                       0.084148           1.683024
# 151    0.493664                       0.151347           1.061574
# ..          ...                            ...                ...
# 1      0.355280                       0.400770           2.313707
# 2      0.475540                       0.153527           2.322715
# 128    0.385923                       0.068106           1.042941
# 0      0.362012                       0.315964           2.277027
# 46     0.415984                       0.246528           1.816914
#
# [155 rows x 12 columns]

# %% [markdown]
# ### Sort descending
#
# To sort from highest to lowest, we must provide  `ascending=False` as an argument to `sort_values()`

# %%
happiness_df.sort_values("Freedom", ascending = False)
# Out:
#         Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 46   Uzbekistan              47            5.971      6.065538     5.876463
# 0        Norway               1            7.537      7.594445     7.479556
# 128    Cambodia             129            4.168      4.278518     4.057483
# 2       Iceland               3            7.504      7.622030     7.385970
# 1       Denmark               2            7.522      7.581728     7.462272
# ..          ...             ...              ...           ...          ...
# 151       Syria             152            3.462      3.663669     3.260331
# 153     Burundi             154            2.905      3.074690     2.735310
# 144       Haiti             145            3.603      3.734715     3.471285
# 129       Sudan             130            4.139      4.345747     3.932253
# 139      Angola             140            3.795      3.951642     3.638358
#
#      Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 46                   0.786441  1.548969                  0.498273  0.658249
# 0                    1.616463  1.533524                  0.796667  0.635423
# 128                  0.601765  1.006238                  0.429783  0.633376
# 2                    1.480633  1.610574                  0.833552  0.627163
# 1                    1.482383  1.551122                  0.792566  0.626007
# ..                        ...       ...                       ...       ...
# 151                  0.777153  0.396103                  0.500533  0.081539
# 153                  0.091623  0.629794                  0.151611  0.059901
# 144                  0.368610  0.640450                  0.277321  0.030370
# 129                  0.659517  1.214009                  0.290921  0.014996
# 139                  0.858428  1.104412                  0.049869  0.000000
#
#      Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 46     0.415984                       0.246528           1.816914
# 0      0.362012                       0.315964           2.277027
# 128    0.385923                       0.068106           1.042941
# 2      0.475540                       0.153527           2.322715
# 1      0.355280                       0.400770           2.313707
# ..          ...                            ...                ...
# 151    0.493664                       0.151347           1.061574
# 153    0.204435                       0.084148           1.683024
# 144    0.489204                       0.099872           1.697168
# 129    0.182317                       0.089848           1.687066
# 139    0.097926                       0.069720           1.614482
#
# [155 rows x 12 columns]

# %% [markdown]
# ### Sorting based on multiple columns
#
# **NOTE:** When sorting my multiple columns, the function will prioritize the columns in the order that they are provided in the list.

# %%
# In case of a tie in Family, Generosity is used to place the order
sorted_df = happiness_df.sort_values(['Family', 'Generosity'], ascending = False)

# %% [markdown]
# ### Reset the index
#
# After we sort, the rows will be in a different order, but they will still maintain their pre-sort indexes, which means that the row at index 0 will not necessarily be the row with the highest/lowest value. By resetting the index, we update the indexes to reflect the new sort order.
#
# The `drop=True` argument for `reset_index()` simply means that we don't want to have the original indexes stored as a column in the dataFrame. We just want to drop them.

# %%
sorted_df.reset_index(drop = True)
# Out:
#                       Country  Happiness.Rank  Happiness.Score  Whisker.high  \
# 0                     Iceland               3            7.504      7.622030
# 1                     Ireland              15            6.977      7.043352
# 2                     Denmark               2            7.522      7.581728
# 3                  Uzbekistan              47            5.971      6.065538
# 4                 New Zealand               8            7.314      7.379510
# ..                        ...             ...              ...           ...
# 150                    Malawi             136            3.970      4.077479
# 151                     Benin             143            3.657      3.745784
# 152                      Togo             150            3.495      3.594038
# 153                     Syria             152            3.462      3.663669
# 154  Central African Republic             155            2.693      2.864884
#
#      Whisker.low  Economy..GDP.per.Capita.    Family  \
# 0       7.385970                  1.480633  1.610574
# 1       6.910649                  1.535707  1.558231
# 2       7.462272                  1.482383  1.551122
# 3       5.876463                  0.786441  1.548969
# 4       7.248490                  1.405706  1.548195
# ..           ...                       ...       ...
# 150     3.862521                  0.233442  0.512569
# 151     3.568217                  0.431085  0.435300
# 152     3.395962                  0.305445  0.431883
# 153     3.260331                  0.777153  0.396103
# 154     2.521116                  0.000000  0.000000
#
#      Health..Life.Expectancy.   Freedom  Generosity  \
# 0                    0.833552  0.627163    0.475540
# 1                    0.809783  0.573110    0.427858
# 2                    0.792566  0.626007    0.355280
# 3                    0.498273  0.658249    0.415984
# 4                    0.816760  0.614062    0.500005
# ..                        ...       ...         ...
# 150                  0.315090  0.466915    0.287170
# 151                  0.209930  0.425963    0.207948
# 152                  0.247106  0.380426    0.196896
# 153                  0.500533  0.081539    0.493664
# 154                  0.018773  0.270842    0.280876
#
#      Trust..Government.Corruption.  Dystopia.Residual
# 0                         0.153527           2.322715
# 1                         0.298388           1.773869
# 2                         0.400770           2.313707
# 3                         0.246528           1.816914
# 4                         0.382817           2.046456
# ..                             ...                ...
# 150                       0.072712           2.081786
# 151                       0.060929           1.885631
# 152                       0.095665           1.837229
# 153                       0.151347           1.061574
# 154                       0.056565           2.066005
#
# [155 rows x 12 columns]

# %%
sorted_df[sorted_df['Country']=='United States']
# Out:
#           Country  Happiness.Rank  Happiness.Score  Whisker.high  Whisker.low  \
# 13  United States              14            6.993      7.074657     6.911343
#
#     Economy..GDP.per.Capita.    Family  Health..Life.Expectancy.   Freedom  \
# 13                  1.546259  1.419921                  0.774287  0.505741
#
#     Generosity  Trust..Government.Corruption.  Dystopia.Residual
# 13    0.392579                       0.135639           2.218113
